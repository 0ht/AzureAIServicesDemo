# %% [markdown]
# # ファイルからコンテンツを抽出する

# %% [markdown]
# このノートブックでは **Azure AI Content Understanding API** を使って、ドキュメント / 音声 / 動画 などマルチモーダルなファイルからセマンティックなコンテンツを抽出する方法を示します。

# %% [markdown]
# ## 前提条件
# 1. すでに `CONTENT_UNDERSTANDING_ENDPOINT` と `CONTENT_UNDERSTANDING_KEY` が `.env.dev` に設定されていること。
# 2. このリポジトリの `data/` フォルダにサンプルファイル (例: `invoice.pdf`, `audio.wav`, `FlightSimulator.mp4`) を配置してください。
# 3. 必要な Python パッケージをインストールしていない場合は下記セルを実行してください。

# %%
# %pip install python-dotenv Pillow requests

# %% [markdown]
# ## クライアントの初期化 (APIキー方式のみ)
# `content_understanding_client.py` は最小実装版です。完全版が必要な場合は公式サンプルから取得して置き換えてください。
# 環境変数: `CONTENT_UNDERSTANDING_ENDPOINT`, `CONTENT_UNDERSTANDING_KEY` を利用します。

# %%
import os, json, logging, uuid, re, importlib, asyncio
from pathlib import Path
from dotenv import load_dotenv, find_dotenv, dotenv_values
from PIL import Image
from io import BytesIO

load_dotenv(find_dotenv())
logging.basicConfig(level=logging.INFO)

# ノートブックから見たリポジトリルートへの相対パス (demos/openai から ../../ でルートへ)
repo_root = Path(__file__).parent.parent.parent if '__file__' in globals() else Path.cwd().parent.parent
env_path = repo_root / '.env.dev'

if env_path.exists():
    # dotenv_values で .env.dev を辞書として読み込む
    parsed = dotenv_values(env_path)
    # 各キーを os.environ に書き込む(空文字や None はスキップ)
    for k, v in parsed.items():
        if v:
            os.environ[k] = v
    print(f'環境変数を読み込みました: {env_path}')
    print(f'{len(parsed)} 個のキーをパースし、os.environ に設定しました。')
else:
    print(f'警告: {env_path} が見つかりません。')


ENDPOINT = os.getenv('CONTENT_UNDERSTANDING_ENDPOINT')
API_KEY = os.getenv('CONTENT_UNDERSTANDING_KEY')
API_VERSION = '2025-05-01-preview'  # 必要に応じて更新

if not ENDPOINT or not API_KEY:
    raise RuntimeError('環境変数 CONTENT_UNDERSTANDING_ENDPOINT / CONTENT_UNDERSTANDING_KEY が設定されていません')

# モジュール再読込 (開いているカーネルが古い定義を持っている場合に備える)
import content_understanding_client
importlib.reload(content_understanding_client)
from content_understanding_client import AzureContentUnderstandingClient, POLL_TIMEOUT_SECONDS

# 非同期メソッドがない古い版を使用中なら動的に追加
if not hasattr(AzureContentUnderstandingClient, 'analyze_and_get_result_async'):
    async def analyze_and_get_result_async(self, analyzer_id: str, file_location: str, timeout_seconds: int = POLL_TIMEOUT_SECONDS, polling_interval_seconds: int = 2):
        resp = await asyncio.to_thread(self.begin_analyze, analyzer_id, file_location)
        return await asyncio.to_thread(self.poll_result, resp, timeout_seconds, polling_interval_seconds)
    AzureContentUnderstandingClient.analyze_and_get_result_async = analyze_and_get_result_async  # type: ignore
    async def begin_analyze_async(self, analyzer_id: str, file_location: str):
        return await asyncio.to_thread(self.begin_analyze, analyzer_id, file_location)
    AzureContentUnderstandingClient.begin_analyze_async = begin_analyze_async  # type: ignore
    async def poll_result_async(self, response, timeout_seconds: int = POLL_TIMEOUT_SECONDS, polling_interval_seconds: int = 2):
        return await asyncio.to_thread(self.poll_result, response, timeout_seconds, polling_interval_seconds)
    AzureContentUnderstandingClient.poll_result_async = poll_result_async  # type: ignore

client = AzureContentUnderstandingClient(endpoint=ENDPOINT, api_version=API_VERSION, subscription_key=API_KEY, x_ms_useragent='azure-ai-content-understanding-demo/content_extraction_jp')

print('Client initialized. Async methods available:', all(hasattr(client, m) for m in ['analyze_and_get_result_async','begin_analyze_async','poll_result_async']))

def save_image(image_id: str, analyze_response):
    raw = client.get_image_from_analyze_operation(analyze_response, image_id)
    if not raw:
        print(f'画像 {image_id} を取得できませんでした')
        return
    img = Image.open(BytesIO(raw))
    Path('.cache').mkdir(exist_ok=True)
    out_path = Path(f'.cache/{image_id}.jpg')
    img.save(out_path, 'JPEG')
    print(f'Saved {out_path}')
# Out:
# 環境変数を読み込みました: c:\Users\toohta\Gitrepos\AzureAIServicesDemo\.env.dev
# 13 個のキーをパースし、os.environ に設定しました。
# Client initialized. Async methods available: True

# %% [markdown]
# ## ドキュメント コンテンツ抽出
# `invoice.pdf` を解析し、テキストとレイアウト (テーブル / 図) を Markdown と構造化 JSON で得ます。

# %%
DOC_FILE = '../data/invoice.pdf'
ANALYZER_ID = 'prebuilt-documentAnalyzer'

if not Path(DOC_FILE).is_file():
    print(f'サンプルファイルが見つかりません: {DOC_FILE}'); result_doc = None
else:
    resp = client.begin_analyze(ANALYZER_ID, file_location=DOC_FILE)
    result_doc = client.poll_result(resp)
    print(json.dumps(result_doc, indent=2))  # フル出力が長い場合は頭のみ表示
# Out:
# {
#   "id": "bf732e18-b7b3-4412-97f3-6febeaad218b",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "prebuilt-documentAnalyzer",
#     "apiVersion": "2025-05-01-preview",
#     "createdAt": "2025-11-13T02:10:10Z",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "# \u8acb\u6c42\u66f8\n\n\u8acb\u6c42\u65e5: \u5e74\u6708\u65e5\n\n\u8acb\u6c42\u66f8\u756a\u53f7:\n\n\u682a\u5f0f\u4f1a\u793e\n\u5fa1\u4e2d\n\n\u3012\n\n\u96fb\u8a71\u756a\u53f7:\n\u30e1\u30fc\u30eb\u30a2\u30c9\u30ec\u30b9:\n\n\u8acb\u6c42\u91d1\u984d\n\u5186\n\n\n<table>\n<tr>\n<th>\u54c1\u540d</th>\n<th>\u5358\u4fa1</th>\n<th>\u6570\u91cf</th>\n<th>\u91d1\u984d</th>\n</tr>\n<tr>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<td>\u5c0f\u8a08</td>\n<td></td>\n</tr>\n<tr>\n<td>\u6d88\u8cbb\u7a0e</td>\n<td></td>\n</tr>\n<tr>\n<td>\u5408\u8a08</td>\n<td></td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<td>\u632f\u8fbc\u671f\u65e5:</td>\n<td>\u5e74 \u6708 \u65e5</td>\n</tr>\n<tr>\n<td>\u9280\u884c</td>\n<td>\u652f\u5e97 \u666e\u901a</td>\n</tr>\n</table>\n\n\n\u5099\u8003:\n\n<!-- PageBreak -->\n\n\n## \u8acb\u6c42\u66f8\n\n\u8acb\u6c42\u65e5:2025\u5e744\u670830\u65e5\n\n\u8acb\u6c42\u66f8\u756a\u53f7: S-202504-001\n\n\u682a\u5f0f\u4f1a\u793e\u3007\u3007\u5fa1\u4e2d\n\u2610\n\u2610\n\n\u30a2\u30c9\u30d3\u30c7\u30b6\u30a4\u30f3\u4e8b\u52d9\u6240 \u30a2\u30c9\u30d3\u82b1\u5b50\n\n\u3012000-0000\n\u6771\u4eac\u90fd\u54c1\u5ddd\u533a\u5927\u5d0e0-0-0 \u25cb\u25cb\u30d3\u30eb5F\n\u2610\n\u2610\n\n\u96fb\u8a71\u756a\u53f7:00-0000-0000\n\n\u30e1\u30fc\u30eb\u30a2\u30c9\u30ec\u30b9:\u25cb\u25cb@example.com\n\u2610\n\u2610\n\n\u8acb\u6c42\u91d1\u984d\n330,000\u5186\n\n\n<table>\n<tr>\n<th>\u54c1\u540d</th>\n<th>\u5358\u4fa1</th>\n<th>\u6570\u91cf</th>\n<th>\u91d1\u984d</th>\n</tr>\n<tr>\n<td>2025\u5e744\u670814\u65e5 \u30ed\u30b4\u30c7\u30b6\u30a4\u30f3\u5236\u4f5c</td>\n<td>100,000\u5186</td>\n<td>1\u500b</td>\n<td>100,000\u5186</td>\n</tr>\n<tr>\n<td>2025\u5e744\u670821\u65e5 LP\u30c7\u30b6\u30a4\u30f3\u5236\u4f5c</td>\n<td>200,000\u5186</td>\n<td>1\u30da\u30fc\u30b8</td>\n<td>200,000\u5186</td>\n</tr>\n<tr>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<td>\u5c0f\u8a08</td>\n<td>300,000\u5186</td>\n</tr>\n<tr>\n<td>\u6d88\u8cbb\u7a0e</td>\n<td>30,000\u5186</td>\n</tr>\n<tr>\n<td>\u5408\u8a08</td>\n<td>330,000\u5186</td>\n</tr>\n</table>\n\n\n\u632f\u8fbc\u671f\u65e5:2025\u5e745\u670831\u65e5\n\u25cb\u25cb\u9280\u884c \u3007\u3007\u652f\u5e97 \u666e\u901a 1234567\n\u2610\n\u2610\n\u2610\n\u2610\n\n\u30a2\u30c9\u30d3\u30c7\u30b6\u30a4\u30f3\u30b8\u30e0\u30b7\u30e7 \u30a2\u30c9\u30d3\u30cf\u30ca\u30b3\n\n\u5099\u8003:\n\n\u6050\u308c\u5165\u308a\u307e\u3059\u304c\u3001\u632f\u8fbc\u624b\u6570\u6599\u306f\u8cb4\u793e\u306b\u3066\u3054\u8ca0\u62c5\u9858\u3044\u307e\u3059\u3002\n",
#         "fields": {
#           "Summary": {
#             "type": "string",
#             "valueString": "This document is an invoice dated April 30, 2025, issued by Adobe Design Office to a company, detailing services such as logo and LP design with a total amount of 330,000 yen, including tax. The payment is due by May 31, 2025, and the bank details are provided for the transfer."
#           }
#         },
#         "kind": "document",
#         "startPageNumber": 1,
#         "endPageNumber": 2,
#         "unit": "inch",
#         "pages": [
#           {
#             "pageNumber": 1,
#             "angle": 0.0243124,
#             "width": 8.2778,
#             "height": 11.6944,
#             "spans": [
#               {
#                 "offset": 0,
#                 "length": 637
#               }
#             ],
#             "words": [
#               {
#                 "content": "\u8acb",
#                 "span": {
#                   "offset": 2,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,3.7528,0.5904,3.9302,0.5874,3.9297,0.8508,3.7527,0.8508)"
#               },
#               {
#                 "content": "\u6c42",
#                 "span": {
#                   "offset": 3,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,4.0384,0.5881,4.2072,0.5898,4.2069,0.8508,4.0379,0.8508)"
#               },
#               {
#                 "content": "\u66f8",
#                 "span": {
#                   "offset": 4,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,4.2807,0.5893,4.5074,0.588,4.5074,0.8508,4.2804,0.8508)"
#               },
#               {
#                 "content": "\u8acb",
#                 "span": {
#                   "offset": 7,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,4.9953,0.9906,5.0922,0.9927,5.0919,1.1384,4.9949,1.1383)"
#               },
#               {
#                 "content": "\u6c42",
#                 "span": {
#                   "offset": 8,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.1324,0.993,5.2246,0.995,5.2242,1.1379,5.1321,1.1384)"
#               },
#               {
#                 "content": "\u65e5",
#                 "span": {
#                   "offset": 9,
#                   "length": 1
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,5.2458,0.9948,5.338,0.9943,5.3377,1.1382,5.2454,1.1377)"
#               },
#               {
#                 "content": ":",
#                 "span": {
#                   "offset": 10,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,5.3404,0.9943,5.4042,0.9936,5.4038,1.1387,5.34,1.1383)"
#               },
#               {
#                 "content": "\u5e74",
#                 "span": {
#                   "offset": 12,
#                   "length": 1
#                 },
#                 "confidence": 0.991,
#                 "source": "D(1,5.5555,0.9944,5.6736,0.9963,5.6731,1.1374,5.555,1.1375)"
#               },
#               {
#                 "content": "\u6708",
#                 "span": {
#                   "offset": 13,
#                   "length": 1
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,5.7327,0.995,5.8391,0.9939,5.8386,1.1385,5.7324,1.137)"
#               },
#               {
#                 "content": "\u65e5",
#                 "span": {
#                   "offset": 14,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,5.9313,0.9939,6.0384,0.995,6.0384,1.1383,5.9308,1.139)"
#               },
#               {
#                 "content": "\u8acb",
#                 "span": {
#                   "offset": 17,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,4.9938,1.2338,5.0903,1.2338,5.0901,1.377,4.9936,1.3788)"
#               },
#               {
#                 "content": "\u6c42",
#                 "span": {
#                   "offset": 18,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.1304,1.2338,5.2222,1.2333,5.2219,1.3766,5.1301,1.3771)"
#               },
#               {
#                 "content": "\u66f8",
#                 "span": {
#                   "offset": 19,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.2622,1.2331,5.3541,1.234,5.3539,1.3764,5.262,1.3767)"
#               },
#               {
#                 "content": "\u756a",
#                 "span": {
#                   "offset": 20,
#                   "length": 1
#                 },
#                 "confidence": 0.984,
#                 "source": "D(1,5.3753,1.2343,5.5048,1.2339,5.5046,1.3772,5.3751,1.3764)"
#               },
#               {
#                 "content": "\u53f7",
#                 "span": {
#                   "offset": 21,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.5071,1.2339,5.599,1.2325,5.5987,1.377,5.5069,1.3772)"
#               },
#               {
#                 "content": ":",
#                 "span": {
#                   "offset": 22,
#                   "length": 1
#                 },
#                 "confidence": 0.991,
#                 "source": "D(1,5.6013,1.2325,5.667,1.2316,5.667,1.3764,5.601,1.3769)"
#               },
#               {
#                 "content": "\u682a",
#                 "span": {
#                   "offset": 25,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.4675,1.7195,0.5932,1.7208,0.5932,1.9072,0.4676,1.9072)"
#               },
#               {
#                 "content": "\u5f0f",
#                 "span": {
#                   "offset": 26,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.6453,1.7212,0.7649,1.7205,0.7647,1.9067,0.6453,1.9072)"
#               },
#               {
#                 "content": "\u4f1a",
#                 "span": {
#                   "offset": 27,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.817,1.7205,0.9366,1.7203,0.9362,1.9072,0.8168,1.9072)"
#               },
#               {
#                 "content": "\u793e",
#                 "span": {
#                   "offset": 28,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.9887,1.7198,1.1426,1.7206,1.1426,1.9072,0.9883,1.9072)"
#               },
#               {
#                 "content": "\u5fa1",
#                 "span": {
#                   "offset": 30,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,1.5437,1.7248,1.6657,1.7262,1.6653,1.9069,1.5433,1.9061)"
#               },
#               {
#                 "content": "\u4e2d",
#                 "span": {
#                   "offset": 31,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,1.7163,1.7249,1.8738,1.7233,1.8738,1.9066,1.7158,1.9063)"
#               },
#               {
#                 "content": "\u3012",
#                 "span": {
#                   "offset": 34,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,5.0175,2.3392,5.1186,2.3395,5.1186,2.4553,5.0168,2.4554)"
#               },
#               {
#                 "content": "\u96fb",
#                 "span": {
#                   "offset": 37,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.003,2.8009,5.1159,2.8005,5.1158,2.9407,5.0029,2.9407)"
#               },
#               {
#                 "content": "\u8a71",
#                 "span": {
#                   "offset": 38,
#                   "length": 1
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,5.1182,2.8005,5.2264,2.7996,5.2264,2.9406,5.1181,2.9407)"
#               },
#               {
#                 "content": "\u756a",
#                 "span": {
#                   "offset": 39,
#                   "length": 1
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,5.2656,2.8,5.3738,2.8005,5.3738,2.9407,5.2656,2.9404)"
#               },
#               {
#                 "content": "\u53f7",
#                 "span": {
#                   "offset": 40,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.3945,2.8005,5.4844,2.8003,5.4843,2.9407,5.3946,2.9406)"
#               },
#               {
#                 "content": ":",
#                 "span": {
#                   "offset": 41,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,5.4867,2.8002,5.5414,2.7991,5.5414,2.9407,5.4866,2.9407)"
#               },
#               {
#                 "content": "\u30e1",
#                 "span": {
#                   "offset": 43,
#                   "length": 1
#                 },
#                 "confidence": 0.977,
#                 "source": "D(1,5.009,3.0397,5.0984,3.0406,5.0982,3.1712,5.009,3.1727)"
#               },
#               {
#                 "content": "\u30fc",
#                 "span": {
#                   "offset": 44,
#                   "length": 1
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,5.118,3.04,5.203,3.0383,5.2027,3.1719,5.1179,3.1716)"
#               },
#               {
#                 "content": "\u30eb",
#                 "span": {
#                   "offset": 45,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.2401,3.0385,5.3252,3.0388,5.3249,3.1706,5.2398,3.1717)"
#               },
#               {
#                 "content": "\u30a2",
#                 "span": {
#                   "offset": 46,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.3797,3.0379,5.4647,3.0398,5.4643,3.1711,5.3793,3.171)"
#               },
#               {
#                 "content": "\u30c9",
#                 "span": {
#                   "offset": 47,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,5.5018,3.0401,5.6043,3.0401,5.6037,3.173,5.5013,3.1713)"
#               },
#               {
#                 "content": "\u30ec",
#                 "span": {
#                   "offset": 48,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.6239,3.04,5.709,3.0393,5.7083,3.1736,5.6233,3.173)"
#               },
#               {
#                 "content": "\u30b9",
#                 "span": {
#                   "offset": 49,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.7635,3.0388,5.8486,3.0381,5.8479,3.1734,5.7628,3.1737)"
#               },
#               {
#                 "content": ":",
#                 "span": {
#                   "offset": 50,
#                   "length": 1
#                 },
#                 "confidence": 0.991,
#                 "source": "D(1,5.8508,3.0381,5.9184,3.0378,5.9184,3.173,5.8501,3.1734)"
#               },
#               {
#                 "content": "\u8acb",
#                 "span": {
#                   "offset": 53,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,0.4643,3.5752,0.6079,3.5775,0.6075,3.791,0.4644,3.7916)"
#               },
#               {
#                 "content": "\u6c42",
#                 "span": {
#                   "offset": 54,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.6956,3.5778,0.8322,3.5778,0.8319,3.7914,0.6952,3.7916)"
#               },
#               {
#                 "content": "\u91d1",
#                 "span": {
#                   "offset": 55,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,0.9199,3.578,1.0566,3.5774,1.0566,3.791,0.9197,3.7904)"
#               },
#               {
#                 "content": "\u984d",
#                 "span": {
#                   "offset": 56,
#                   "length": 1
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,1.1161,3.578,1.3139,3.5779,1.3139,3.7914,1.1161,3.7908)"
#               },
#               {
#                 "content": "\u5186",
#                 "span": {
#                   "offset": 58,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,2.2733,3.5928,2.4679,3.5922,2.4679,3.7914,2.2735,3.7905)"
#               },
#               {
#                 "content": "\u54c1",
#                 "span": {
#                   "offset": 79,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,2.0075,4.1725,2.1148,4.1737,2.1146,4.3337,2.0072,4.334)"
#               },
#               {
#                 "content": "\u540d",
#                 "span": {
#                   "offset": 80,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,2.1383,4.1737,2.2794,4.1747,2.2792,4.334,2.1382,4.3336)"
#               },
#               {
#                 "content": "\u5358",
#                 "span": {
#                   "offset": 91,
#                   "length": 1
#                 },
#                 "confidence": 0.991,
#                 "source": "D(1,4.2859,4.1718,4.3909,4.1736,4.3901,4.33,4.2849,4.3283)"
#               },
#               {
#                 "content": "\u4fa1",
#                 "span": {
#                   "offset": 92,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,4.4345,4.1738,4.5702,4.1749,4.5702,4.3313,4.4336,4.3302)"
#               },
#               {
#                 "content": "\u6570",
#                 "span": {
#                   "offset": 103,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.5092,4.1707,5.6149,4.1728,5.6149,4.3283,5.509,4.3283)"
#               },
#               {
#                 "content": "\u91cf",
#                 "span": {
#                   "offset": 104,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.6588,4.173,5.7981,4.1732,5.7979,4.3283,5.6587,4.3283)"
#               },
#               {
#                 "content": "\u91d1",
#                 "span": {
#                   "offset": 115,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,6.9073,4.1728,7.0324,4.1745,7.0323,4.3301,6.9072,4.3312)"
#               },
#               {
#                 "content": "\u984d",
#                 "span": {
#                   "offset": 116,
#                   "length": 1
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,7.0553,4.1741,7.1981,4.1739,7.1981,4.3302,7.0553,4.3297)"
#               },
#               {
#                 "content": "\u5c0f",
#                 "span": {
#                   "offset": 412,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,4.2929,6.8476,4.3779,6.8466,4.3778,7.0034,4.2927,7.0043)"
#               },
#               {
#                 "content": "\u8a08",
#                 "span": {
#                   "offset": 413,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,4.4217,6.8469,4.5702,6.846,4.5702,7.0045,4.4217,7.0033)"
#               },
#               {
#                 "content": "\u6d88",
#                 "span": {
#                   "offset": 445,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,4.2177,7.2612,4.3246,7.2617,4.3247,7.4209,4.2176,7.4211)"
#               },
#               {
#                 "content": "\u8cbb",
#                 "span": {
#                   "offset": 446,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,4.3689,7.2619,4.4706,7.2619,4.4703,7.4203,4.3689,7.4213)"
#               },
#               {
#                 "content": "\u7a0e",
#                 "span": {
#                   "offset": 447,
#                   "length": 1
#                 },
#                 "confidence": 0.953,
#                 "source": "D(1,4.5149,7.2614,4.6388,7.262,4.6388,7.4205,4.5148,7.4206)"
#               },
#               {
#                 "content": "\u5408",
#                 "span": {
#                   "offset": 479,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,4.294,7.6781,4.3994,7.6788,4.399,7.8344,4.2937,7.8344)"
#               },
#               {
#                 "content": "\u8a08",
#                 "span": {
#                   "offset": 480,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,4.4225,7.6792,4.5702,7.6796,4.5702,7.8344,4.4223,7.8344)"
#               },
#               {
#                 "content": "\u632f",
#                 "span": {
#                   "offset": 531,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.4648,8.5457,0.5759,8.546,0.5757,8.6852,0.4646,8.6852)"
#               },
#               {
#                 "content": "\u8fbc",
#                 "span": {
#                   "offset": 532,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.5963,8.5463,0.6848,8.5461,0.6845,8.685,0.5961,8.6852)"
#               },
#               {
#                 "content": "\u671f",
#                 "span": {
#                   "offset": 533,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.7234,8.5465,0.8118,8.5466,0.8116,8.6835,0.7231,8.6845)"
#               },
#               {
#                 "content": "\u65e5",
#                 "span": {
#                   "offset": 534,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,0.8503,8.546,0.9388,8.5465,0.9385,8.6839,0.8501,8.6837)"
#               },
#               {
#                 "content": ":",
#                 "span": {
#                   "offset": 535,
#                   "length": 1
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,0.9773,8.5473,1.0569,8.5483,1.0569,8.6841,0.977,8.684)"
#               },
#               {
#                 "content": "\u5e74",
#                 "span": {
#                   "offset": 546,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,1.2028,8.5442,1.3299,8.5456,1.3295,8.6824,1.2024,8.6823)"
#               },
#               {
#                 "content": "\u6708",
#                 "span": {
#                   "offset": 548,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,1.3901,8.5466,1.4949,8.5471,1.4945,8.6834,1.3898,8.682)"
#               },
#               {
#                 "content": "\u65e5",
#                 "span": {
#                   "offset": 550,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,1.5863,8.5489,1.6853,8.5489,1.6853,8.6844,1.586,8.6829)"
#               },
#               {
#                 "content": "\u9280",
#                 "span": {
#                   "offset": 572,
#                   "length": 1
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,0.7177,8.7794,0.8276,8.7794,0.8275,8.9158,0.7176,8.9169)"
#               },
#               {
#                 "content": "\u884c",
#                 "span": {
#                   "offset": 573,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.8478,8.7799,0.9769,8.7782,0.9769,8.9151,0.8476,8.9163)"
#               },
#               {
#                 "content": "\u652f",
#                 "span": {
#                   "offset": 584,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,1.2403,8.7774,1.3577,8.7781,1.3578,8.9235,1.2405,8.9238)"
#               },
#               {
#                 "content": "\u5e97",
#                 "span": {
#                   "offset": 585,
#                   "length": 1
#                 },
#                 "confidence": 0.99,
#                 "source": "D(1,1.3792,8.7773,1.4966,8.7753,1.4966,8.9211,1.3793,8.9235)"
#               },
#               {
#                 "content": "\u666e",
#                 "span": {
#                   "offset": 587,
#                   "length": 1
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,1.5302,8.7748,1.6451,8.7739,1.645,8.9207,1.5301,8.9213)"
#               },
#               {
#                 "content": "\u901a",
#                 "span": {
#                   "offset": 588,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,1.6859,8.7733,1.7824,8.7745,1.7824,8.9202,1.6857,8.9205)"
#               },
#               {
#                 "content": "\u5099",
#                 "span": {
#                   "offset": 612,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,0.5407,9.4989,0.6626,9.4981,0.6624,9.6494,0.5407,9.6502)"
#               },
#               {
#                 "content": "\u8003",
#                 "span": {
#                   "offset": 613,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.7049,9.4981,0.8019,9.4968,0.8016,9.6496,0.7047,9.6499)"
#               },
#               {
#                 "content": ":",
#                 "span": {
#                   "offset": 614,
#                   "length": 1
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,0.8044,9.4967,0.8626,9.4955,0.8626,9.6491,0.8041,9.6496)"
#               }
#             ],
#             "lines": [
#               {
#                 "content": "\u8acb\u6c42\u66f8",
#                 "source": "D(1,3.7528,0.5869,4.5028,0.588,4.5024,0.8508,3.7524,0.8498)",
#                 "span": {
#                   "offset": 2,
#                   "length": 3
#                 }
#               },
#               {
#                 "content": "\u8acb\u6c42\u65e5: \u5e74\u6708\u65e5",
#                 "source": "D(1,4.9953,0.9906,6.0335,0.9933,6.0332,1.1386,4.9949,1.1359)",
#                 "span": {
#                   "offset": 7,
#                   "length": 8
#                 }
#               },
#               {
#                 "content": "\u8acb\u6c42\u66f8\u756a\u53f7:",
#                 "source": "D(1,4.9932,1.2338,5.6617,1.2317,5.6621,1.3748,4.9936,1.3769)",
#                 "span": {
#                   "offset": 17,
#                   "length": 6
#                 }
#               },
#               {
#                 "content": "\u682a\u5f0f\u4f1a\u793e",
#                 "source": "D(1,0.4675,1.7195,1.1403,1.7195,1.1403,1.9048,0.4675,1.9048)",
#                 "span": {
#                   "offset": 25,
#                   "length": 4
#                 }
#               },
#               {
#                 "content": "\u5fa1\u4e2d",
#                 "source": "D(1,1.5429,1.724,1.8706,1.7233,1.8711,1.9035,1.5433,1.9043)",
#                 "span": {
#                   "offset": 30,
#                   "length": 2
#                 }
#               },
#               {
#                 "content": "\u3012",
#                 "source": "D(1,5.0174,2.3388,5.1139,2.3393,5.1133,2.4554,5.0168,2.455)",
#                 "span": {
#                   "offset": 34,
#                   "length": 1
#                 }
#               },
#               {
#                 "content": "\u96fb\u8a71\u756a\u53f7:",
#                 "source": "D(1,5.0026,2.7999,5.54,2.7989,5.5403,2.9389,5.0029,2.9399)",
#                 "span": {
#                   "offset": 37,
#                   "length": 5
#                 }
#               },
#               {
#                 "content": "\u30e1\u30fc\u30eb\u30a2\u30c9\u30ec\u30b9:",
#                 "source": "D(1,5.009,3.0373,5.9151,3.0379,5.915,3.1716,5.0089,3.171)",
#                 "span": {
#                   "offset": 43,
#                   "length": 8
#                 }
#               },
#               {
#                 "content": "\u8acb\u6c42\u91d1\u984d",
#                 "source": "D(1,0.4643,3.5752,1.3084,3.5748,1.3085,3.7895,0.4644,3.79)",
#                 "span": {
#                   "offset": 53,
#                   "length": 4
#                 }
#               },
#               {
#                 "content": "\u5186",
#                 "source": "D(1,2.2729,3.5914,2.4636,3.5908,2.4641,3.7879,2.2735,3.7885)",
#                 "span": {
#                   "offset": 58,
#                   "length": 1
#                 }
#               },
#               {
#                 "content": "\u54c1\u540d",
#                 "source": "D(1,2.0075,4.1725,2.2753,4.1732,2.2749,4.3321,2.0071,4.3315)",
#                 "span": {
#                   "offset": 79,
#                   "length": 2
#                 }
#               },
#               {
#                 "content": "\u5358\u4fa1",
#                 "source": "D(1,4.2859,4.1718,4.5692,4.1748,4.5675,4.3293,4.2846,4.3262)",
#                 "span": {
#                   "offset": 91,
#                   "length": 2
#                 }
#               },
#               {
#                 "content": "\u6570\u91cf",
#                 "source": "D(1,5.5092,4.1707,5.7941,4.1714,5.7937,4.3283,5.5088,4.3277)",
#                 "span": {
#                   "offset": 103,
#                   "length": 2
#                 }
#               },
#               {
#                 "content": "\u91d1\u984d",
#                 "source": "D(1,6.9073,4.1728,7.1949,4.1731,7.1947,4.3288,6.9072,4.3286)",
#                 "span": {
#                   "offset": 115,
#                   "length": 2
#                 }
#               },
#               {
#                 "content": "\u5c0f\u8a08",
#                 "source": "D(1,4.2927,6.8459,4.5669,6.8459,4.5669,7.002,4.2927,7.002)",
#                 "span": {
#                   "offset": 412,
#                   "length": 2
#                 }
#               },
#               {
#                 "content": "\u6d88\u8cbb\u7a0e",
#                 "source": "D(1,4.2177,7.2612,4.6384,7.2614,4.6383,7.4191,4.2176,7.4189)",
#                 "span": {
#                   "offset": 445,
#                   "length": 3
#                 }
#               },
#               {
#                 "content": "\u5408\u8a08",
#                 "source": "D(1,4.294,7.6781,4.5674,7.6791,4.5668,7.8343,4.2934,7.8332)",
#                 "span": {
#                   "offset": 479,
#                   "length": 2
#                 }
#               },
#               {
#                 "content": "\u632f\u8fbc\u671f\u65e5:",
#                 "source": "D(1,0.464,8.5455,1.0553,8.5428,1.0559,8.6821,0.4646,8.6848)",
#                 "span": {
#                   "offset": 531,
#                   "length": 5
#                 }
#               },
#               {
#                 "content": "\u5e74 \u6708 \u65e5",
#                 "source": "D(1,1.2028,8.5442,1.685,8.5462,1.6845,8.6823,1.2022,8.6802)",
#                 "span": {
#                   "offset": 546,
#                   "length": 5
#                 }
#               },
#               {
#                 "content": "\u9280\u884c",
#                 "source": "D(1,0.7167,8.7794,0.9722,8.7777,0.9731,8.9134,0.7176,8.9151)",
#                 "span": {
#                   "offset": 572,
#                   "length": 2
#                 }
#               },
#               {
#                 "content": "\u652f\u5e97 \u666e\u901a",
#                 "source": "D(1,1.2397,8.777,1.7789,8.7723,1.7802,8.9176,1.2405,8.9223)",
#                 "span": {
#                   "offset": 584,
#                   "length": 5
#                 }
#               },
#               {
#                 "content": "\u5099\u8003:",
#                 "source": "D(1,0.5403,9.4964,0.8601,9.4955,0.8605,9.6472,0.5407,9.648)",
#                 "span": {
#                   "offset": 612,
#                   "length": 3
#                 }
#               }
#             ]
#           },
#           {
#             "pageNumber": 2,
#             "angle": 0.01546819,
#             "width": 8.2778,
#             "height": 11.6944,
#             "spans": [
#               {
#                 "offset": 637,
#                 "length": 826
#               }
#             ],
#             "words": [
#               {
#                 "content": "\u8acb",
#                 "span": {
#                   "offset": 641,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(2,3.7529,0.5858,3.9362,0.5847,3.9353,0.8565,3.7524,0.8565)"
#               },
#               {
#                 "content": "\u6c42",
#                 "span": {
#                   "offset": 642,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(2,4.0479,0.5845,4.2222,0.5864,4.2216,0.8565,4.0471,0.8565)"
#               },
#               {
#                 "content": "\u66f8",
#                 "span": {
#                   "offset": 643,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,4.2982,0.5861,4.5074,0.5856,4.5074,0.8565,4.2974,0.8565)"
#               },
#               {
#                 "content": "\u8acb",
#                 "span": {
#                   "offset": 646,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(2,4.9923,0.9892,5.0921,0.9902,5.0916,1.1404,4.9918,1.141)"
#               },
#               {
#                 "content": "\u6c42",
#                 "span": {
#                   "offset": 647,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.1334,0.9906,5.2283,0.9906,5.2278,1.1396,5.133,1.14)"
#               },
#               {
#                 "content": "\u65e5",
#                 "span": {
#                   "offset": 648,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.2502,0.9904,5.345,0.9912,5.3446,1.1393,5.2497,1.1396)"
#               },
#               {
#                 "content": ":2025",
#                 "span": {
#                   "offset": 649,
#                   "length": 5
#                 },
#                 "confidence": 0.986,
#                 "source": "D(2,5.3474,0.9912,5.7147,0.9914,5.7139,1.1386,5.347,1.1393)"
#               },
#               {
#                 "content": "\u5e74",
#                 "span": {
#                   "offset": 654,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.7171,0.9915,5.812,0.9916,5.8112,1.1388,5.7163,1.1386)"
#               },
#               {
#                 "content": "4",
#                 "span": {
#                   "offset": 655,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.8339,0.9915,5.9093,0.9909,5.9087,1.1383,5.8332,1.1389)"
#               },
#               {
#                 "content": "\u6708",
#                 "span": {
#                   "offset": 656,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.9117,0.9909,6.0066,0.991,6.006,1.1376,5.9112,1.1383)"
#               },
#               {
#                 "content": "30",
#                 "span": {
#                   "offset": 657,
#                   "length": 2
#                 },
#                 "confidence": 0.991,
#                 "source": "D(2,6.009,0.991,6.1622,0.9907,6.1615,1.139,6.0085,1.1375)"
#               },
#               {
#                 "content": "\u65e5",
#                 "span": {
#                   "offset": 659,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,6.1646,0.9907,6.2955,0.9909,6.2954,1.137,6.1639,1.139)"
#               },
#               {
#                 "content": "\u8acb",
#                 "span": {
#                   "offset": 662,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(2,4.9919,1.23,5.0909,1.2309,5.0904,1.3794,4.9912,1.3802)"
#               },
#               {
#                 "content": "\u6c42",
#                 "span": {
#                   "offset": 663,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.1319,1.2311,5.2261,1.2311,5.2255,1.3798,5.1314,1.3795)"
#               },
#               {
#                 "content": "\u66f8",
#                 "span": {
#                   "offset": 664,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.2671,1.231,5.3613,1.2311,5.3608,1.3797,5.2666,1.38)"
#               },
#               {
#                 "content": "\u756a",
#                 "span": {
#                   "offset": 665,
#                   "length": 1
#                 },
#                 "confidence": 0.985,
#                 "source": "D(2,5.383,1.2311,5.5158,1.2308,5.5154,1.3795,5.3826,1.3794)"
#               },
#               {
#                 "content": "\u53f7",
#                 "span": {
#                   "offset": 666,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.5182,1.2308,5.593,1.2318,5.5927,1.3791,5.5178,1.3795)"
#               },
#               {
#                 "content": ":",
#                 "span": {
#                   "offset": 667,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(2,5.5954,1.2318,5.6558,1.2324,5.6554,1.3789,5.5951,1.3791)"
#               },
#               {
#                 "content": "S-202504-001",
#                 "span": {
#                   "offset": 669,
#                   "length": 12
#                 },
#                 "confidence": 0.977,
#                 "source": "D(2,5.692,1.2324,6.4783,1.2322,6.4783,1.377,5.6916,1.3788)"
#               },
#               {
#                 "content": "\u682a",
#                 "span": {
#                   "offset": 683,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,0.465,1.7159,0.5976,1.7179,0.5967,1.9165,0.4643,1.917)"
#               },
#               {
#                 "content": "\u5f0f",
#                 "span": {
#                   "offset": 684,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,0.6267,1.718,0.7529,1.7179,0.7521,1.9146,0.6259,1.9167)"
#               },
#               {
#                 "content": "\u4f1a",
#                 "span": {
#                   "offset": 685,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,0.8079,1.7178,0.934,1.7174,0.9333,1.9141,0.807,1.9134)"
#               },
#               {
#                 "content": "\u793e",
#                 "span": {
#                   "offset": 686,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(2,0.989,1.7169,1.1151,1.7157,1.1145,1.9138,0.9883,1.9145)"
#               },
#               {
#                 "content": "\u3007",
#                 "span": {
#                   "offset": 687,
#                   "length": 1
#                 },
#                 "confidence": 0.738,
#                 "source": "D(2,1.1443,1.7156,1.2704,1.7152,1.2696,1.9142,1.1437,1.9141)"
#               },
#               {
#                 "content": "\u3007",
#                 "span": {
#                   "offset": 688,
#                   "length": 1
#                 },
#                 "confidence": 0.724,
#                 "source": "D(2,1.3254,1.7166,1.5033,1.7195,1.5022,1.914,1.3245,1.9138)"
#               },
#               {
#                 "content": "\u5fa1",
#                 "span": {
#                   "offset": 689,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,1.5485,1.7204,1.6844,1.7187,1.6833,1.9145,1.5473,1.9149)"
#               },
#               {
#                 "content": "\u4e2d",
#                 "span": {
#                   "offset": 690,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(2,1.7135,1.7181,1.8795,1.7159,1.8795,1.9154,1.7124,1.9144)"
#               },
#               {
#                 "content": "\u2610",
#                 "span": {
#                   "offset": 692,
#                   "length": 1
#                 },
#                 "confidence": 0.484,
#                 "source": "D(2,1.185,1.7395,1.3285,1.7406,1.3286,1.8907,1.1799,1.8923)"
#               },
#               {
#                 "content": "\u2610",
#                 "span": {
#                   "offset": 694,
#                   "length": 1
#                 },
#                 "confidence": 0.418,
#                 "source": "D(2,1.3529,1.7394,1.4968,1.7396,1.4944,1.8926,1.3506,1.8922)"
#               },
#               {
#                 "content": "\u30a2",
#                 "span": {
#                   "offset": 697,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.0083,2.0312,5.1398,2.0314,5.1387,2.2264,5.0075,2.226)"
#               },
#               {
#                 "content": "\u30c9",
#                 "span": {
#                   "offset": 698,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.1686,2.0314,5.2936,2.0314,5.2928,2.227,5.1675,2.2265)"
#               },
#               {
#                 "content": "\u30d3",
#                 "span": {
#                   "offset": 699,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.3225,2.0314,5.4475,2.0312,5.4469,2.227,5.3217,2.227)"
#               },
#               {
#                 "content": "\u30c7",
#                 "span": {
#                   "offset": 700,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.502,2.0311,5.627,2.0319,5.6261,2.2268,5.5013,2.2269)"
#               },
#               {
#                 "content": "\u30b6",
#                 "span": {
#                   "offset": 701,
#                   "length": 1
#                 },
#                 "confidence": 0.994,
#                 "source": "D(2,5.6559,2.0323,5.8065,2.0328,5.8054,2.227,5.6548,2.2269)"
#               },
#               {
#                 "content": "\u30a4",
#                 "span": {
#                   "offset": 702,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.8354,2.0326,5.9604,2.0321,5.9594,2.227,5.8343,2.227)"
#               },
#               {
#                 "content": "\u30f3",
#                 "span": {
#                   "offset": 703,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(2,5.9636,2.0321,6.1142,2.0323,6.1129,2.227,5.9626,2.227)"
#               },
#               {
#                 "content": "\u4e8b",
#                 "span": {
#                   "offset": 704,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,6.1687,2.0328,6.2937,2.0338,6.2925,2.227,6.1674,2.227)"
#               },
#               {
#                 "content": "\u52d9",
#                 "span": {
#                   "offset": 705,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,6.3482,2.0334,6.4732,2.0326,6.472,2.2264,6.347,2.227)"
#               },
#               {
#                 "content": "\u6240",
#                 "span": {
#                   "offset": 706,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,6.5021,2.0325,6.6656,2.032,6.6646,2.2263,6.501,2.2263)"
#               },
#               {
#                 "content": "\u30a2",
#                 "span": {
#                   "offset": 708,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,6.7233,2.0317,6.8322,2.0313,6.8307,2.227,6.7221,2.227)"
#               },
#               {
#                 "content": "\u30c9",
#                 "span": {
#                   "offset": 709,
#                   "length": 1
#                 },
#                 "confidence": 0.994,
#                 "source": "D(2,6.8611,2.0313,7.0118,2.0315,7.0105,2.227,6.8596,2.227)"
#               },
#               {
#                 "content": "\u30d3",
#                 "span": {
#                   "offset": 710,
#                   "length": 1
#                 },
#                 "confidence": 0.994,
#                 "source": "D(2,7.015,2.0315,7.1656,2.0312,7.1644,2.2268,7.0137,2.227)"
#               },
#               {
#                 "content": "\u82b1",
#                 "span": {
#                   "offset": 711,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,7.2201,2.0311,7.3451,2.0308,7.344,2.227,7.2189,2.227)"
#               },
#               {
#                 "content": "\u5b50",
#                 "span": {
#                   "offset": 712,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,7.374,2.0308,7.5465,2.0305,7.5459,2.227,7.3729,2.227)"
#               },
#               {
#                 "content": "\u3012",
#                 "span": {
#                   "offset": 715,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(2,5.0132,2.333,5.104,2.3341,5.1034,2.4688,5.0127,2.4691)"
#               },
#               {
#                 "content": "000-0000",
#                 "span": {
#                   "offset": 716,
#                   "length": 8
#                 },
#                 "confidence": 0.983,
#                 "source": "D(2,5.1062,2.3341,5.6613,2.334,5.6613,2.4691,5.1056,2.4688)"
#               },
#               {
#                 "content": "\u6771",
#                 "span": {
#                   "offset": 725,
#                   "length": 1
#                 },
#                 "confidence": 1,
#                 "source": "D(2,4.9979,2.5599,5.12,2.5602,5.1193,2.7123,4.9971,2.7121)"
#               },
#               {
#                 "content": "\u4eac",
#                 "span": {
#                   "offset": 726,
#                   "length": 1
#                 },
#                 "confidence": 1,
#                 "source": "D(2,5.1224,2.5602,5.2196,2.5601,5.219,2.7123,5.1218,2.7123)"
#               },
#               {
#                 "content": "\u90fd",
#                 "span": {
#                   "offset": 727,
#                   "length": 1
#                 },
#                 "confidence": 1,
#                 "source": "D(2,5.262,2.56,5.3591,2.5597,5.3585,2.7123,5.2613,2.7123)"
#               },
#               {
#                 "content": "\u54c1",
#                 "span": {
#                   "offset": 728,
#                   "length": 1
#                 },
#                 "confidence": 1,
#                 "source": "D(2,5.3816,2.5596,5.4787,2.5599,5.4782,2.7123,5.381,2.7123)"
#               },
#               {
#                 "content": "\u5ddd",
#                 "span": {
#                   "offset": 729,
#                   "length": 1
#                 },
#                 "confidence": 0.999,
#                 "source": "D(2,5.4812,2.5599,5.5784,2.5606,5.5779,2.7123,5.4807,2.7123)"
#               },
#               {
# ...
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "\u652f\u5e97 \u666e\u901a",
#                 "source": "D(1,1.1254,8.7309,1.8338,8.7309,1.8338,8.9764,1.1311,8.9764)",
#                 "span": {
#                   "offset": 584,
#                   "length": 5
#                 },
#                 "elements": [
#                   "/paragraphs/17"
#                 ]
#               }
#             ],
#             "source": "D(1,0.4286,8.5054,1.8207,8.5054,1.8206,8.9652,0.4283,8.9651)",
#             "span": {
#               "offset": 514,
#               "length": 95
#             }
#           },
#           {
#             "rowCount": 6,
#             "columnCount": 4,
#             "cells": [
#               {
#                 "kind": "columnHeader",
#                 "rowIndex": 0,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "\u54c1\u540d",
#                 "source": "D(2,0.4667,4.024,3.8104,4.024,3.8104,4.4476,0.4743,4.4476)",
#                 "span": {
#                   "offset": 831,
#                   "length": 2
#                 },
#                 "elements": [
#                   "/paragraphs/28"
#                 ]
#               },
#               {
#                 "kind": "columnHeader",
#                 "rowIndex": 0,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "\u5358\u4fa1",
#                 "source": "D(2,3.8104,4.024,5.0284,4.024,5.0284,4.4476,3.8104,4.4476)",
#                 "span": {
#                   "offset": 843,
#                   "length": 2
#                 },
#                 "elements": [
#                   "/paragraphs/29"
#                 ]
#               },
#               {
#                 "kind": "columnHeader",
#                 "rowIndex": 0,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "\u6570\u91cf",
#                 "source": "D(2,5.0284,4.024,6.2615,4.024,6.2615,4.4476,5.0284,4.4476)",
#                 "span": {
#                   "offset": 855,
#                   "length": 2
#                 },
#                 "elements": [
#                   "/paragraphs/30"
#                 ]
#               },
#               {
#                 "kind": "columnHeader",
#                 "rowIndex": 0,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "\u91d1\u984d",
#                 "source": "D(2,6.2615,4.024,7.8198,4.0165,7.8198,4.4476,6.2615,4.4476)",
#                 "span": {
#                   "offset": 867,
#                   "length": 2
#                 },
#                 "elements": [
#                   "/paragraphs/31"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "2025\u5e744\u670814\u65e5 \u30ed\u30b4\u30c7\u30b6\u30a4\u30f3\u5236\u4f5c",
#                 "source": "D(2,0.4743,4.4476,3.8104,4.4476,3.8104,4.856,0.4743,4.856)",
#                 "span": {
#                   "offset": 890,
#                   "length": 19
#                 },
#                 "elements": [
#                   "/paragraphs/32"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "100,000\u5186",
#                 "source": "D(2,3.8104,4.4476,5.0284,4.4476,5.0284,4.856,3.8104,4.856)",
#                 "span": {
#                   "offset": 919,
#                   "length": 8
#                 },
#                 "elements": [
#                   "/paragraphs/33"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "1\u500b",
#                 "source": "D(2,5.0284,4.4476,6.2615,4.4476,6.2615,4.856,5.0284,4.856)",
#                 "span": {
#                   "offset": 937,
#                   "length": 2
#                 },
#                 "elements": [
#                   "/paragraphs/34"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "100,000\u5186",
#                 "source": "D(2,6.2615,4.4476,7.8198,4.4476,7.8198,4.856,6.2615,4.856)",
#                 "span": {
#                   "offset": 949,
#                   "length": 8
#                 },
#                 "elements": [
#                   "/paragraphs/35"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "2025\u5e744\u670821\u65e5 LP\u30c7\u30b6\u30a4\u30f3\u5236\u4f5c",
#                 "source": "D(2,0.4743,4.856,3.8104,4.856,3.8104,5.2796,0.4743,5.2645)",
#                 "span": {
#                   "offset": 978,
#                   "length": 19
#                 },
#                 "elements": [
#                   "/paragraphs/36"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "200,000\u5186",
#                 "source": "D(2,3.8104,4.856,5.0284,4.856,5.0284,5.2796,3.8104,5.2796)",
#                 "span": {
#                   "offset": 1007,
#                   "length": 8
#                 },
#                 "elements": [
#                   "/paragraphs/37"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "1\u30da\u30fc\u30b8",
#                 "source": "D(2,5.0284,4.856,6.2615,4.856,6.2615,5.2796,5.0284,5.2796)",
#                 "span": {
#                   "offset": 1025,
#                   "length": 4
#                 },
#                 "elements": [
#                   "/paragraphs/38"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "200,000\u5186",
#                 "source": "D(2,6.2615,4.856,7.8198,4.856,7.8198,5.2872,6.2615,5.2796)",
#                 "span": {
#                   "offset": 1039,
#                   "length": 8
#                 },
#                 "elements": [
#                   "/paragraphs/39"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,0.4743,5.2645,3.8104,5.2796,3.8104,5.6956,0.4743,5.6881)",
#                 "span": {
#                   "offset": 1068,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,3.8104,5.2796,5.0284,5.2796,5.0284,5.6956,3.8104,5.6956)",
#                 "span": {
#                   "offset": 1078,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,5.0284,5.2796,6.2615,5.2796,6.2615,5.7032,5.0284,5.6956)",
#                 "span": {
#                   "offset": 1088,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,6.2615,5.2796,7.8198,5.2872,7.8198,5.7032,6.2615,5.7032)",
#                 "span": {
#                   "offset": 1098,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 4,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,0.4743,5.6881,3.8104,5.6956,3.8104,6.1116,0.4743,6.1041)",
#                 "span": {
#                   "offset": 1119,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 4,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,3.8104,5.6956,5.0284,5.6956,5.0284,6.1116,3.8104,6.1116)",
#                 "span": {
#                   "offset": 1129,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 4,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,5.0284,5.6956,6.2615,5.7032,6.2615,6.1192,5.0284,6.1116)",
#                 "span": {
#                   "offset": 1139,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 4,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,6.2615,5.7032,7.8198,5.7032,7.8198,6.1192,6.2615,6.1192)",
#                 "span": {
#                   "offset": 1149,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 5,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,0.4743,6.1041,3.8104,6.1116,3.8104,6.5276,0.4743,6.5201)",
#                 "span": {
#                   "offset": 1170,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 5,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,3.8104,6.1116,5.0284,6.1116,5.0284,6.5276,3.8104,6.5276)",
#                 "span": {
#                   "offset": 1180,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 5,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,5.0284,6.1116,6.2615,6.1192,6.2539,6.5352,5.0284,6.5276)",
#                 "span": {
#                   "offset": 1190,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 5,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(2,6.2615,6.1192,7.8198,6.1192,7.8123,6.5352,6.2539,6.5352)",
#                 "span": {
#                   "offset": 1200,
#                   "length": 0
#                 }
#               }
#             ],
#             "source": "D(2,0.4623,4.0153,7.8399,4.0151,7.8404,6.5417,0.4624,6.5412)",
#             "span": {
#               "offset": 814,
#               "length": 406
#             }
#           },
#           {
#             "rowCount": 3,
#             "columnCount": 2,
#             "cells": [
#               {
#                 "kind": "content",
#                 "rowIndex": 0,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "\u5c0f\u8a08",
#                 "source": "D(2,3.8104,6.6923,5.0329,6.6923,5.0329,7.1092,3.8104,7.1149)",
#                 "span": {
#                   "offset": 1240,
#                   "length": 2
#                 },
#                 "elements": [
#                   "/paragraphs/40"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 0,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "300,000\u5186",
#                 "source": "D(2,5.0329,6.6923,7.8093,6.6866,7.815,7.1092,5.0329,7.1092)",
#                 "span": {
#                   "offset": 1252,
#                   "length": 8
#                 },
#                 "elements": [
#                   "/paragraphs/41"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "\u6d88\u8cbb\u7a0e",
#                 "source": "D(2,3.8104,7.1149,5.0329,7.1092,5.0329,7.5317,3.8104,7.5317)",
#                 "span": {
#                   "offset": 1281,
#                   "length": 3
#                 },
#                 "elements": [
#                   "/paragraphs/42"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "30,000\u5186",
#                 "source": "D(2,5.0329,7.1092,7.815,7.1092,7.8208,7.5317,5.0329,7.5317)",
#                 "span": {
#                   "offset": 1294,
#                   "length": 7
#                 },
#                 "elements": [
#                   "/paragraphs/43"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "\u5408\u8a08",
#                 "source": "D(2,3.8104,7.5317,5.0329,7.5317,5.0329,7.9429,3.8104,7.9429)",
#                 "span": {
#                   "offset": 1322,
#                   "length": 2
#                 },
#                 "elements": [
#                   "/paragraphs/44"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "330,000\u5186",
#                 "source": "D(2,5.0329,7.5317,7.8208,7.5317,7.8265,7.9429,5.0329,7.9429)",
#                 "span": {
#                   "offset": 1334,
#                   "length": 8
#                 },
#                 "elements": [
#                   "/paragraphs/45"
#                 ]
#               }
#             ],
#             "source": "D(2,3.8039,6.6836,7.8305,6.6835,7.8299,7.953,3.8023,7.953)",
#             "span": {
#               "offset": 1223,
#               "length": 139
#             }
#           }
#         ]
#       }
#     ]
#   },
#   "usage": {
#     "documentPages": 2,
#     "tokens": {
#       "contextualization": 2000,
#       "input": 1953,
#       "output": 85
#     }
#   }
# }

# %% [markdown]
# ### 抽出された Markdown 表示

# %%
if result_doc:
    md = result_doc['result']['contents'][0].get('markdown', '')
    print(md[:4000])
# Out:
# # 請求書
#
# 請求日: 年月日
#
# 請求書番号:
#
# 株式会社
# 御中
#
# 〒
#
# 電話番号:
# メールアドレス:
#
# 請求金額
# 円
#
#
# <table>
# <tr>
# <th>品名</th>
# <th>単価</th>
# <th>数量</th>
# <th>金額</th>
# </tr>
# <tr>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </table>
#
#
# <table>
# <tr>
# <td>小計</td>
# <td></td>
# </tr>
# <tr>
# <td>消費税</td>
# <td></td>
# </tr>
# <tr>
# <td>合計</td>
# <td></td>
# </tr>
# </table>
#
#
# <table>
# <tr>
# <td>振込期日:</td>
# <td>年 月 日</td>
# </tr>
# <tr>
# <td>銀行</td>
# <td>支店 普通</td>
# </tr>
# </table>
#
#
# 備考:
#
# <!-- PageBreak -->
#
#
# ## 請求書
#
# 請求日:2025年4月30日
#
# 請求書番号: S-202504-001
#
# 株式会社〇〇御中
# ☐
# ☐
#
# アドビデザイン事務所 アドビ花子
#
# 〒000-0000
# 東京都品川区大崎0-0-0 ○○ビル5F
# ☐
# ☐
#
# 電話番号:00-0000-0000
#
# メールアドレス:○○@example.com
# ☐
# ☐
#
# 請求金額
# 330,000円
#
#
# <table>
# <tr>
# <th>品名</th>
# <th>単価</th>
# <th>数量</th>
# <th>金額</th>
# </tr>
# <tr>
# <td>2025年4月14日 ロゴデザイン制作</td>
# <td>100,000円</td>
# <td>1個</td>
# <td>100,000円</td>
# </tr>
# <tr>
# <td>2025年4月21日 LPデザイン制作</td>
# <td>200,000円</td>
# <td>1ページ</td>
# <td>200,000円</td>
# </tr>
# <tr>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </table>
#
#
# <table>
# <tr>
# <td>小計</td>
# <td>300,000円</td>
# </tr>
# <tr>
# <td>消費税</td>
# <td>30,000円</td>
# </tr>
# <tr>
# <td>合計</td>
# <td>330,000円</td>
# </tr>
# </table>
#
#
# 振込期日:2025年5月31日
# ○○銀行 〇〇支店 普通 1234567
# ☐
# ☐
# ☐
# ☐
#
# アドビデザインジムショ アドビハナコ
#
# 備考:
#
# 恐れ入りますが、振込手数料は貴社にてご負担願います。

# %% [markdown]
# ### レイアウト構造 (pages / tables など)

# %%
if result_doc:
    content0 = result_doc['result']['contents'][0]
    print(json.dumps(content0.get('tables', []), indent=2)[:2000])
# Out:
# [
#   {
#     "rowCount": 6,
#     "columnCount": 4,
#     "cells": [
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "\u54c1\u540d",
#         "source": "D(1,0.4731,4.0247,3.8115,4.0247,3.8115,4.4494,0.4731,4.4494)",
#         "span": {
#           "offset": 79,
#           "length": 2
#         },
#         "elements": [
#           "/paragraphs/7"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "\u5358\u4fa1",
#         "source": "D(1,3.8115,4.0247,5.033,4.0247,5.033,4.4494,3.8115,4.4494)",
#         "span": {
#           "offset": 91,
#           "length": 2
#         },
#         "elements": [
#           "/paragraphs/8"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 2,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "\u6570\u91cf",
#         "source": "D(1,5.033,4.0247,6.2622,4.0247,6.2622,4.4494,5.033,4.4494)",
#         "span": {
#           "offset": 103,
#           "length": 2
#         },
#         "elements": [
#           "/paragraphs/9"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 3,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "\u91d1\u984d",
#         "source": "D(1,6.2622,4.0247,7.8251,4.0323,7.8251,4.4494,6.2622,4.4494)",
#         "span": {
#           "offset": 115,
#           "length": 2
#         },
#         "elements": [
#           "/paragraphs/10"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "",
#         "source": "D(1,0.4731,4.4494,3.8115,4.4494,3.8115,4.8589,0.4731,4.8589)",
#         "span": {
#           "offset": 138,
#           "length": 0
#         }
#       },
#       {
#         "kind": "content",

# %% [markdown]
# ## 音声コンテンツ解析
# 話者識別 / タイムスタンプ / 信頼度などが含まれます。

# %%
AUDIO_FILE = '../data/sampleTokyo.wav'
AUDIO_ANALYZER_ID = 'prebuilt-audioAnalyzer'

if not Path(AUDIO_FILE).is_file():
    print(f'サンプル音声が見つかりません: {AUDIO_FILE}'); audio_result = None
else:
    resp = client.begin_analyze(AUDIO_ANALYZER_ID, file_location=AUDIO_FILE)
    audio_result = client.poll_result(resp)
    print(json.dumps(audio_result, indent=2))
# Out:
# {
#   "id": "f62a45f4-db80-4254-9061-60fefda3743a",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "prebuilt-audioAnalyzer",
#     "apiVersion": "2025-05-01-preview",
#     "createdAt": "2025-11-13T02:20:16Z",
#     "stringEncoding": "utf8",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "# Audio: 00:00.000 => 00:48.193\n\nTranscript\n```\nWEBVTT\n\n00:00.040 --> 00:29.360\n<v Speaker 1>\u6d45\u91ce\u670b\u7f8e\u3067\u3059\u3002\u4eca\u65e5\u306e\u6771\u4eac\u682a\u5f0f\u5e02\u5834\u3067\u3001\u65e5\u7d4c\u5e73\u5747\u682a\u4fa1\u306f\u5c0f\u5e45\u7d9a\u4f38\u3068\u306a\u3063\u3066\u3044\u307e\u3059\u3002\u7d42\u5024\u306f\u6628\u65e5\u306b\u6bd4\u307922\u518672\u92ad\u9ad8\u306e11,088\u518658\u92ad\u3067\u3057\u305f\u3002\u6771\u8a3c\u4e00\u90e8\u306e\u5024\u4e0a\u304c\u308a\u9298\u67c4\u6570\u306f1146\u3001\u5bfe\u3057\u3066\u5024\u4e0b\u304c\u308a\u306f368\u3001\u5909\u308f\u3089\u305a\u306f104\u9298\u67c4\u3068\u306a\u3063\u3066\u3044\u307e\u3059\u3002\u3053\u3053\u3067\u30d7\u30ec\u30bc\u30f3\u30c8\u306e\u304a\u77e5\u3089\u305b\u3067\u3059\u3002\n\n00:29.600 --> 00:48.160\n<v Speaker 1>\u3053\u306e\u756a\u7d44\u3067\u306f\u3001\u6bce\u6708\u767a\u884c\u306e\u30de\u30f3\u30b9\u30ea\u30fc\u30ec\u30dd\u30fc\u30c84\u6708\u53f7\u3092\u62bd\u9078\u3067\u5341\u540d\u69d8\u306b\u30d7\u30ec\u30bc\u30f3\u30c8\u3044\u305f\u3057\u307e\u3059\u3002\u304a\u7533\u3057\u8fbc\u307f\u306f\u304a\u96fb\u8a71\u3067\u6771\u4eac03010783730301078373\u307e\u3067\u3002\u4ee5\u4e0a\u3001\u756a\u7d44\u304b\u3089\u306e\u304a\u77e5\u3089\u305b\u3067\u3057\u305f\u3002\n```",
#         "fields": {
#           "Summary": {
#             "type": "string",
#             "valueString": "The conversation is a news report by Speaker 1, Asano Tomomi, about the Tokyo stock market. The Nikkei 225 index saw a slight increase, closing at 11,088.58 yen, up by 22.72 yen from the previous day. There were 1,146 stocks that rose, 368 that fell, and 104 that remained unchanged on the Tokyo Stock Exchange. Additionally, the program announced a giveaway of ten copies of the April issue of their monthly report, with applications accepted via phone at the provided Tokyo number."
#           }
#         },
#         "kind": "audioVisual",
#         "startTimeMs": 0,
#         "endTimeMs": 48193,
#         "transcriptPhrases": [
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 40,
#             "endTimeMs": 29360,
#             "text": "\u6d45\u91ce\u670b\u7f8e\u3067\u3059\u3002\u4eca\u65e5\u306e\u6771\u4eac\u682a\u5f0f\u5e02\u5834\u3067\u3001\u65e5\u7d4c\u5e73\u5747\u682a\u4fa1\u306f\u5c0f\u5e45\u7d9a\u4f38\u3068\u306a\u3063\u3066\u3044\u307e\u3059\u3002\u7d42\u5024\u306f\u6628\u65e5\u306b\u6bd4\u307922\u518672\u92ad\u9ad8\u306e11,088\u518658\u92ad\u3067\u3057\u305f\u3002\u6771\u8a3c\u4e00\u90e8\u306e\u5024\u4e0a\u304c\u308a\u9298\u67c4\u6570\u306f1146\u3001\u5bfe\u3057\u3066\u5024\u4e0b\u304c\u308a\u306f368\u3001\u5909\u308f\u3089\u305a\u306f104\u9298\u67c4\u3068\u306a\u3063\u3066\u3044\u307e\u3059\u3002\u3053\u3053\u3067\u30d7\u30ec\u30bc\u30f3\u30c8\u306e\u304a\u77e5\u3089\u305b\u3067\u3059\u3002",
#             "confidence": 0.92,
#             "words": [
#               {
#                 "startTimeMs": 40,
#                 "endTimeMs": 240,
#                 "text": "\u6d45"
#               },
#               {
#                 "startTimeMs": 240,
#                 "endTimeMs": 320,
#                 "text": "\u91ce"
#               },
#               {
#                 "startTimeMs": 320,
#                 "endTimeMs": 560,
#                 "text": "\u670b"
#               },
#               {
#                 "startTimeMs": 560,
#                 "endTimeMs": 640,
#                 "text": "\u7f8e"
#               },
#               {
#                 "startTimeMs": 640,
#                 "endTimeMs": 800,
#                 "text": "\u3067"
#               },
#               {
#                 "startTimeMs": 800,
#                 "endTimeMs": 920,
#                 "text": "\u3059"
#               },
#               {
#                 "startTimeMs": 920,
#                 "endTimeMs": 1080,
#                 "text": "\u3002"
#               },
#               {
#                 "startTimeMs": 2160,
#                 "endTimeMs": 2320,
#                 "text": "\u4eca"
#               },
#               {
#                 "startTimeMs": 2320,
#                 "endTimeMs": 2400,
#                 "text": "\u65e5"
#               },
#               {
#                 "startTimeMs": 2400,
#                 "endTimeMs": 2480,
#                 "text": "\u306e"
#               },
#               {
#                 "startTimeMs": 2480,
#                 "endTimeMs": 2720,
#                 "text": "\u6771"
#               },
#               {
#                 "startTimeMs": 2720,
#                 "endTimeMs": 2800,
#                 "text": "\u4eac"
#               },
#               {
#                 "startTimeMs": 2800,
#                 "endTimeMs": 3040,
#                 "text": "\u682a"
#               },
#               {
#                 "startTimeMs": 3040,
#                 "endTimeMs": 3200,
#                 "text": "\u5f0f"
#               },
#               {
#                 "startTimeMs": 3200,
#                 "endTimeMs": 3440,
#                 "text": "\u5e02"
#               },
#               {
#                 "startTimeMs": 3440,
#                 "endTimeMs": 3520,
#                 "text": "\u5834"
#               },
#               {
#                 "startTimeMs": 3520,
#                 "endTimeMs": 3840,
#                 "text": "\u3067"
#               },
#               {
#                 "startTimeMs": 3840,
#                 "endTimeMs": 3960,
#                 "text": "\u3001"
#               },
#               {
#                 "startTimeMs": 3960,
#                 "endTimeMs": 4080,
#                 "text": "\u65e5"
#               },
#               {
#                 "startTimeMs": 4080,
#                 "endTimeMs": 4160,
#                 "text": "\u7d4c"
#               },
#               {
#                 "startTimeMs": 4160,
#                 "endTimeMs": 4400,
#                 "text": "\u5e73"
#               },
#               {
#                 "startTimeMs": 4400,
#                 "endTimeMs": 4640,
#                 "text": "\u5747"
#               },
#               {
#                 "startTimeMs": 4640,
#                 "endTimeMs": 4880,
#                 "text": "\u682a"
#               },
#               {
#                 "startTimeMs": 4880,
#                 "endTimeMs": 5040,
#                 "text": "\u4fa1"
#               },
#               {
#                 "startTimeMs": 5040,
#                 "endTimeMs": 5200,
#                 "text": "\u306f"
#               },
#               {
#                 "startTimeMs": 5200,
#                 "endTimeMs": 5320,
#                 "text": "\u5c0f"
#               },
#               {
#                 "startTimeMs": 5320,
#                 "endTimeMs": 5600,
#                 "text": "\u5e45"
#               },
#               {
#                 "startTimeMs": 5600,
#                 "endTimeMs": 5800,
#                 "text": "\u7d9a"
#               },
#               {
#                 "startTimeMs": 5800,
#                 "endTimeMs": 6040,
#                 "text": "\u4f38"
#               },
#               {
#                 "startTimeMs": 6040,
#                 "endTimeMs": 6120,
#                 "text": "\u3068"
#               },
#               {
#                 "startTimeMs": 6120,
#                 "endTimeMs": 6240,
#                 "text": "\u306a"
#               },
#               {
#                 "startTimeMs": 6240,
#                 "endTimeMs": 6280,
#                 "text": "\u3063"
#               },
#               {
#                 "startTimeMs": 6280,
#                 "endTimeMs": 6360,
#                 "text": "\u3066"
#               },
#               {
#                 "startTimeMs": 6360,
#                 "endTimeMs": 6480,
#                 "text": "\u3044"
#               },
#               {
#                 "startTimeMs": 6480,
#                 "endTimeMs": 6640,
#                 "text": "\u307e"
#               },
#               {
#                 "startTimeMs": 6640,
#                 "endTimeMs": 6760,
#                 "text": "\u3059"
#               },
#               {
#                 "startTimeMs": 6760,
#                 "endTimeMs": 6920,
#                 "text": "\u3002"
#               },
#               {
#                 "startTimeMs": 7280,
#                 "endTimeMs": 7520,
#                 "text": "\u7d42"
#               },
#               {
#                 "startTimeMs": 7520,
#                 "endTimeMs": 7640,
#                 "text": "\u5024"
#               },
#               {
#                 "startTimeMs": 7640,
#                 "endTimeMs": 7720,
#                 "text": "\u306f"
#               },
#               {
#                 "startTimeMs": 7720,
#                 "endTimeMs": 7920,
#                 "text": "\u6628"
#               },
#               {
#                 "startTimeMs": 7920,
#                 "endTimeMs": 8000,
#                 "text": "\u65e5"
#               },
#               {
#                 "startTimeMs": 8000,
#                 "endTimeMs": 8320,
#                 "text": "\u306b"
#               },
#               {
#                 "startTimeMs": 8320,
#                 "endTimeMs": 8400,
#                 "text": "\u6bd4"
#               },
#               {
#                 "startTimeMs": 8480,
#                 "endTimeMs": 8800,
#                 "text": "\u3079"
#               },
#               {
#                 "startTimeMs": 8880,
#                 "endTimeMs": 9680,
#                 "text": "22"
#               },
#               {
#                 "startTimeMs": 9720,
#                 "endTimeMs": 10160,
#                 "text": "\u5186"
#               },
#               {
#                 "startTimeMs": 10160,
#                 "endTimeMs": 10560,
#                 "text": "72"
#               },
#               {
#                 "startTimeMs": 10560,
#                 "endTimeMs": 10800,
#                 "text": "\u92ad"
#               },
#               {
#                 "startTimeMs": 10800,
#                 "endTimeMs": 11040,
#                 "text": "\u9ad8"
#               },
#               {
#                 "startTimeMs": 11040,
#                 "endTimeMs": 11360,
#                 "text": "\u306e"
#               },
#               {
#                 "startTimeMs": 11520,
#                 "endTimeMs": 13520,
#                 "text": "11,088"
#               },
#               {
#                 "startTimeMs": 13520,
#                 "endTimeMs": 13760,
#                 "text": "\u5186"
#               },
#               {
#                 "startTimeMs": 13760,
#                 "endTimeMs": 14360,
#                 "text": "58"
#               },
#               {
#                 "startTimeMs": 14360,
#                 "endTimeMs": 14560,
#                 "text": "\u92ad"
#               },
#               {
#                 "startTimeMs": 14560,
#                 "endTimeMs": 14640,
#                 "text": "\u3067"
#               },
#               {
#                 "startTimeMs": 14640,
#                 "endTimeMs": 14720,
#                 "text": "\u3057"
#               },
#               {
#                 "startTimeMs": 14720,
#                 "endTimeMs": 14880,
#                 "text": "\u305f"
#               },
#               {
#                 "startTimeMs": 14880,
#                 "endTimeMs": 15040,
#                 "text": "\u3002"
#               },
#               {
#                 "startTimeMs": 16080,
#                 "endTimeMs": 16320,
#                 "text": "\u6771"
#               },
#               {
#                 "startTimeMs": 16320,
#                 "endTimeMs": 16560,
#                 "text": "\u8a3c"
#               },
#               {
#                 "startTimeMs": 16560,
#                 "endTimeMs": 16760,
#                 "text": "\u4e00"
#               },
#               {
#                 "startTimeMs": 16760,
#                 "endTimeMs": 16880,
#                 "text": "\u90e8"
#               },
#               {
#                 "startTimeMs": 16880,
#                 "endTimeMs": 17040,
#                 "text": "\u306e"
#               },
#               {
#                 "startTimeMs": 17040,
#                 "endTimeMs": 17120,
#                 "text": "\u5024"
#               },
#               {
#                 "startTimeMs": 17120,
#                 "endTimeMs": 17200,
#                 "text": "\u4e0a"
#               },
#               {
#                 "startTimeMs": 17200,
#                 "endTimeMs": 17320,
#                 "text": "\u304c"
#               },
#               {
#                 "startTimeMs": 17320,
#                 "endTimeMs": 17440,
#                 "text": "\u308a"
#               },
#               {
#                 "startTimeMs": 17440,
#                 "endTimeMs": 17560,
#                 "text": "\u9298"
#               },
#               {
#                 "startTimeMs": 17560,
#                 "endTimeMs": 17760,
#                 "text": "\u67c4"
#               },
#               {
#                 "startTimeMs": 17760,
#                 "endTimeMs": 18040,
#                 "text": "\u6570"
#               },
#               {
#                 "startTimeMs": 18040,
#                 "endTimeMs": 18800,
#                 "text": "\u306f"
#               },
#               {
#                 "startTimeMs": 18800,
#                 "endTimeMs": 19760,
#                 "text": "1146"
#               },
#               {
#                 "startTimeMs": 19760,
#                 "endTimeMs": 19880,
#                 "text": "\u3001"
#               },
#               {
#                 "startTimeMs": 20320,
#                 "endTimeMs": 20640,
#                 "text": "\u5bfe"
#               },
#               {
#                 "startTimeMs": 20640,
#                 "endTimeMs": 20720,
#                 "text": "\u3057"
#               },
#               {
#                 "startTimeMs": 20720,
#                 "endTimeMs": 20960,
#                 "text": "\u3066"
#               },
#               {
#                 "startTimeMs": 20960,
#                 "endTimeMs": 21040,
#                 "text": "\u5024"
#               },
#               {
#                 "startTimeMs": 21040,
#                 "endTimeMs": 21120,
#                 "text": "\u4e0b"
#               },
#               {
#                 "startTimeMs": 21120,
#                 "endTimeMs": 21200,
#                 "text": "\u304c"
#               },
#               {
#                 "startTimeMs": 21200,
#                 "endTimeMs": 21360,
#                 "text": "\u308a"
#               },
#               {
#                 "startTimeMs": 21360,
#                 "endTimeMs": 21600,
#                 "text": "\u306f"
#               },
#               {
#                 "startTimeMs": 21600,
#                 "endTimeMs": 23040,
#                 "text": "368"
#               },
#               {
#                 "startTimeMs": 23040,
#                 "endTimeMs": 23160,
#                 "text": "\u3001"
#               },
#               {
#                 "startTimeMs": 23440,
#                 "endTimeMs": 23560,
#                 "text": "\u5909"
#               },
#               {
#                 "startTimeMs": 23560,
#                 "endTimeMs": 23760,
#                 "text": "\u308f"
#               },
#               {
#                 "startTimeMs": 23760,
#                 "endTimeMs": 23920,
#                 "text": "\u3089"
#               },
#               {
#                 "startTimeMs": 23920,
#                 "endTimeMs": 24040,
#                 "text": "\u305a"
#               },
#               {
#                 "startTimeMs": 24040,
#                 "endTimeMs": 24240,
#                 "text": "\u306f"
#               },
#               {
#                 "startTimeMs": 24240,
#                 "endTimeMs": 24800,
#                 "text": "104"
#               },
#               {
#                 "startTimeMs": 24800,
#                 "endTimeMs": 24960,
#                 "text": "\u9298"
#               },
#               {
#                 "startTimeMs": 24960,
#                 "endTimeMs": 25200,
#                 "text": "\u67c4"
#               },
#               {
#                 "startTimeMs": 25200,
#                 "endTimeMs": 25280,
#                 "text": "\u3068"
#               },
#               {
#                 "startTimeMs": 25280,
#                 "endTimeMs": 25440,
#                 "text": "\u306a"
#               },
#               {
#                 "startTimeMs": 25440,
#                 "endTimeMs": 25480,
#                 "text": "\u3063"
#               },
#               {
#                 "startTimeMs": 25480,
#                 "endTimeMs": 25560,
#                 "text": "\u3066"
#               },
#               {
#                 "startTimeMs": 25560,
#                 "endTimeMs": 25640,
#                 "text": "\u3044"
#               },
#               {
#                 "startTimeMs": 25640,
#                 "endTimeMs": 25760,
#                 "text": "\u307e"
#               },
#               {
#                 "startTimeMs": 25760,
#                 "endTimeMs": 25840,
#                 "text": "\u3059"
#               },
#               {
#                 "startTimeMs": 25840,
#                 "endTimeMs": 26000,
#                 "text": "\u3002"
#               },
#               {
#                 "startTimeMs": 27520,
#                 "endTimeMs": 27720,
#                 "text": "\u3053"
#               },
#               {
#                 "startTimeMs": 27720,
#                 "endTimeMs": 27840,
#                 "text": "\u3053"
#               },
#               {
#                 "startTimeMs": 27840,
#                 "endTimeMs": 27920,
#                 "text": "\u3067"
#               },
#               {
#                 "startTimeMs": 27920,
#                 "endTimeMs": 28040,
#                 "text": "\u30d7"
#               },
#               {
#                 "startTimeMs": 28040,
#                 "endTimeMs": 28160,
#                 "text": "\u30ec"
#               },
#               {
#                 "startTimeMs": 28160,
#                 "endTimeMs": 28240,
#                 "text": "\u30bc"
#               },
#               {
#                 "startTimeMs": 28240,
#                 "endTimeMs": 28320,
#                 "text": "\u30f3"
#               },
#               {
#                 "startTimeMs": 28320,
#                 "endTimeMs": 28400,
#                 "text": "\u30c8"
#               },
#               {
#                 "startTimeMs": 28400,
#                 "endTimeMs": 28520,
#                 "text": "\u306e"
#               },
#               {
#                 "startTimeMs": 28520,
#                 "endTimeMs": 28600,
#                 "text": "\u304a"
#               },
#               {
#                 "startTimeMs": 28600,
#                 "endTimeMs": 28680,
#                 "text": "\u77e5"
#               },
#               {
#                 "startTimeMs": 28680,
#                 "endTimeMs": 28800,
#                 "text": "\u3089"
#               },
#               {
#                 "startTimeMs": 28800,
#                 "endTimeMs": 28880,
#                 "text": "\u305b"
#               },
#               {
#                 "startTimeMs": 28880,
#                 "endTimeMs": 29040,
#                 "text": "\u3067"
#               },
#               {
#                 "startTimeMs": 29040,
#                 "endTimeMs": 29200,
#                 "text": "\u3059"
#               },
#               {
#                 "startTimeMs": 29200,
#                 "endTimeMs": 29360,
#                 "text": "\u3002"
#               }
#             ],
#             "locale": "ja-JP"
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 29600,
#             "endTimeMs": 48160,
#             "text": "\u3053\u306e\u756a\u7d44\u3067\u306f\u3001\u6bce\u6708\u767a\u884c\u306e\u30de\u30f3\u30b9\u30ea\u30fc\u30ec\u30dd\u30fc\u30c84\u6708\u53f7\u3092\u62bd\u9078\u3067\u5341\u540d\u69d8\u306b\u30d7\u30ec\u30bc\u30f3\u30c8\u3044\u305f\u3057\u307e\u3059\u3002\u304a\u7533\u3057\u8fbc\u307f\u306f\u304a\u96fb\u8a71\u3067\u6771\u4eac03010783730301078373\u307e\u3067\u3002\u4ee5\u4e0a\u3001\u756a\u7d44\u304b\u3089\u306e\u304a\u77e5\u3089\u305b\u3067\u3057\u305f\u3002",
#             "confidence": 0.951,
#             "words": [
#               {
#                 "startTimeMs": 29600,
#                 "endTimeMs": 29720,
#                 "text": "\u3053"
#               },
#               {
#                 "startTimeMs": 29720,
#                 "endTimeMs": 29840,
#                 "text": "\u306e"
#               },
#               {
#                 "startTimeMs": 29840,
#                 "endTimeMs": 30000,
#                 "text": "\u756a"
#               },
#               {
#                 "startTimeMs": 30000,
#                 "endTimeMs": 30160,
#                 "text": "\u7d44"
#               },
#               {
#                 "startTimeMs": 30160,
#                 "endTimeMs": 30320,
#                 "text": "\u3067"
#               },
#               {
#                 "startTimeMs": 30320,
#                 "endTimeMs": 30480,
#                 "text": "\u306f"
#               },
#               {
#                 "startTimeMs": 30480,
#                 "endTimeMs": 30600,
#                 "text": "\u3001"
#               },
#               {
#                 "startTimeMs": 30600,
#                 "endTimeMs": 30760,
#                 "text": "\u6bce"
#               },
#               {
#                 "startTimeMs": 30760,
#                 "endTimeMs": 31040,
#                 "text": "\u6708"
#               },
#               {
#                 "startTimeMs": 31040,
#                 "endTimeMs": 31280,
#                 "text": "\u767a"
#               },
#               {
#                 "startTimeMs": 31280,
#                 "endTimeMs": 31440,
#                 "text": "\u884c"
#               },
#               {
#                 "startTimeMs": 31440,
#                 "endTimeMs": 31600,
#                 "text": "\u306e"
#               },
#               {
#                 "startTimeMs": 31600,
#                 "endTimeMs": 31720,
#                 "text": "\u30de"
#               },
#               {
#                 "startTimeMs": 31720,
#                 "endTimeMs": 31760,
#                 "text": "\u30f3"
#               },
#               {
#                 "startTimeMs": 31760,
#                 "endTimeMs": 31840,
#                 "text": "\u30b9"
#               },
#               {
#                 "startTimeMs": 31840,
#                 "endTimeMs": 31920,
#                 "text": "\u30ea"
#               },
#               {
#                 "startTimeMs": 31920,
#                 "endTimeMs": 32120,
#                 "text": "\u30fc"
#               },
#               {
#                 "startTimeMs": 32120,
#                 "endTimeMs": 32200,
#                 "text": "\u30ec"
#               },
#               {
#                 "startTimeMs": 32200,
#                 "endTimeMs": 32280,
#                 "text": "\u30dd"
#               },
#               {
#                 "startTimeMs": 32280,
#                 "endTimeMs": 32480,
#                 "text": "\u30fc"
#               },
#               {
#                 "startTimeMs": 32480,
#                 "endTimeMs": 32560,
#                 "text": "\u30c8"
#               },
#               {
#                 "startTimeMs": 32560,
#                 "endTimeMs": 32680,
#                 "text": "4"
#               },
#               {
#                 "startTimeMs": 32680,
#                 "endTimeMs": 32960,
#                 "text": "\u6708"
#               },
#               {
#                 "startTimeMs": 32960,
#                 "endTimeMs": 33120,
#                 "text": "\u53f7"
#               },
#               {
#                 "startTimeMs": 33120,
#                 "endTimeMs": 33360,
#                 "text": "\u3092"
#               },
#               {
#                 "startTimeMs": 33440,
#                 "endTimeMs": 33680,
#                 "text": "\u62bd"
#               },
#               {
#                 "startTimeMs": 33680,
#                 "endTimeMs": 33920,
#                 "text": "\u9078"
#               },
#               {
#                 "startTimeMs": 33920,
#                 "endTimeMs": 34080,
#                 "text": "\u3067"
#               },
#               {
#                 "startTimeMs": 34080,
#                 "endTimeMs": 34240,
#                 "text": "\u5341"
#               },
#               {
#                 "startTimeMs": 34240,
#                 "endTimeMs": 34360,
#                 "text": "\u540d"
#               },
#               {
#                 "startTimeMs": 34360,
#                 "endTimeMs": 34640,
#                 "text": "\u69d8"
#               },
#               {
#                 "startTimeMs": 34640,
#                 "endTimeMs": 34800,
#                 "text": "\u306b"
#               },
#               {
#                 "startTimeMs": 34800,
#                 "endTimeMs": 34920,
#                 "text": "\u30d7"
#               },
#               {
#                 "startTimeMs": 34920,
#                 "endTimeMs": 35040,
#                 "text": "\u30ec"
#               },
#               {
#                 "startTimeMs": 35040,
#                 "endTimeMs": 35120,
#                 "text": "\u30bc"
#               },
#               {
#                 "startTimeMs": 35120,
#                 "endTimeMs": 35200,
#                 "text": "\u30f3"
#               },
#               {
#                 "startTimeMs": 35200,
#                 "endTimeMs": 35280,
#                 "text": "\u30c8"
#               },
#               {
#                 "startTimeMs": 35280,
#                 "endTimeMs": 35360,
#                 "text": "\u3044"
#               },
#               {
#                 "startTimeMs": 35360,
#                 "endTimeMs": 35440,
#                 "text": "\u305f"
#               },
#               {
#                 "startTimeMs": 35440,
#                 "endTimeMs": 35560,
#                 "text": "\u3057"
#               },
#               {
#                 "startTimeMs": 35560,
#                 "endTimeMs": 35680,
#                 "text": "\u307e"
#               },
#               {
#                 "startTimeMs": 35680,
#                 "endTimeMs": 35840,
#                 "text": "\u3059"
#               },
#               {
#                 "startTimeMs": 35840,
#                 "endTimeMs": 36000,
#                 "text": "\u3002"
#               },
#               {
#                 "startTimeMs": 36320,
#                 "endTimeMs": 36520,
#                 "text": "\u304a"
#               },
#               {
#                 "startTimeMs": 36520,
#                 "endTimeMs": 36600,
#                 "text": "\u7533"
#               },
#               {
#                 "startTimeMs": 36600,
#                 "endTimeMs": 36720,
#                 "text": "\u3057"
#               },
#               {
#                 "startTimeMs": 36720,
#                 "endTimeMs": 36840,
#                 "text": "\u8fbc"
#               },
#               {
#                 "startTimeMs": 36840,
#                 "endTimeMs": 36960,
#                 "text": "\u307f"
#               },
#               {
#                 "startTimeMs": 36960,
#                 "endTimeMs": 37120,
#                 "text": "\u306f"
#               },
#               {
#                 "startTimeMs": 37120,
#                 "endTimeMs": 37320,
#                 "text": "\u304a"
#               },
#               {
#                 "startTimeMs": 37320,
#                 "endTimeMs": 37480,
#                 "text": "\u96fb"
#               },
#               {
#                 "startTimeMs": 37480,
#                 "endTimeMs": 37760,
#                 "text": "\u8a71"
#               },
#               {
#                 "startTimeMs": 37760,
#                 "endTimeMs": 37840,
#                 "text": "\u3067"
#               },
#               {
#                 "startTimeMs": 38320,
#                 "endTimeMs": 38560,
#                 "text": "\u6771"
#               },
#               {
#                 "startTimeMs": 38560,
#                 "endTimeMs": 38680,
#                 "text": "\u4eac"
#               },
#               {
#                 "startTimeMs": 38680,
#                 "endTimeMs": 45120,
#                 "text": "03010783730301078373"
#               },
#               {
#                 "startTimeMs": 45120,
#                 "endTimeMs": 45200,
#                 "text": "\u307e"
#               },
#               {
#                 "startTimeMs": 45200,
#                 "endTimeMs": 45440,
#                 "text": "\u3067"
#               },
#               {
#                 "startTimeMs": 45440,
#                 "endTimeMs": 45600,
#                 "text": "\u3002"
#               },
#               {
#                 "startTimeMs": 46160,
#                 "endTimeMs": 46320,
#                 "text": "\u4ee5"
#               },
#               {
#                 "startTimeMs": 46320,
#                 "endTimeMs": 46440,
#                 "text": "\u4e0a"
#               },
#               {
#                 "startTimeMs": 46440,
#                 "endTimeMs": 46560,
#                 "text": "\u3001"
#               },
#               {
#                 "startTimeMs": 46560,
#                 "endTimeMs": 46800,
#                 "text": "\u756a"
#               },
#               {
#                 "startTimeMs": 46800,
#                 "endTimeMs": 47040,
#                 "text": "\u7d44"
#               },
#               {
#                 "startTimeMs": 47040,
#                 "endTimeMs": 47120,
#                 "text": "\u304b"
#               },
#               {
#                 "startTimeMs": 47120,
#                 "endTimeMs": 47200,
#                 "text": "\u3089"
#               },
#               {
#                 "startTimeMs": 47200,
#                 "endTimeMs": 47360,
#                 "text": "\u306e"
#               },
#               {
#                 "startTimeMs": 47360,
#                 "endTimeMs": 47520,
#                 "text": "\u304a"
#               },
#               {
#                 "startTimeMs": 47520,
#                 "endTimeMs": 47600,
#                 "text": "\u77e5"
#               },
#               {
#                 "startTimeMs": 47600,
#                 "endTimeMs": 47720,
#                 "text": "\u3089"
#               },
#               {
#                 "startTimeMs": 47720,
#                 "endTimeMs": 47800,
#                 "text": "\u305b"
#               },
#               {
#                 "startTimeMs": 47800,
#                 "endTimeMs": 47880,
#                 "text": "\u3067"
#               },
#               {
#                 "startTimeMs": 47880,
#                 "endTimeMs": 47960,
#                 "text": "\u3057"
#               },
#               {
#                 "startTimeMs": 47960,
#                 "endTimeMs": 48040,
#                 "text": "\u305f"
#               },
#               {
#                 "startTimeMs": 48040,
#                 "endTimeMs": 48160,
#                 "text": "\u3002"
#               }
#             ],
#             "locale": "ja-JP"
#           }
#         ]
#       }
#     ]
#   },
#   "usage": {
#     "audioHours": 0.014,
#     "tokens": {
#       "contextualization": 1361.112,
#       "input": 1471,
#       "output": 123
#     }
#   }
# }

# %%
# 解析結果の markdown 内に Unicode エスケープ (\uXXXX) が残っている場合にデコードするユーティリティ
import re

def _decode_unicode_escape_if_needed(text: str) -> str:
    if not isinstance(text, str):
        return text
    # 単純判定: \uNNNN パターンを含む場合のみデコードを試みる
    if re.search(r"\\u[0-9a-fA-F]{4}", text):
        try:
            # unicode_escape で一旦デコード。過度な \n などは保持されるため適切。
            return bytes(text, "utf-8").decode("unicode_escape")
        except Exception:
            return text  # 失敗時はそのまま返す
    return text

# ドキュメント / 音声 / 動画いずれの result オブジェクトにも対応可能

def decode_markdown_in_result(result_json: dict):
    if not isinstance(result_json, dict):
        return result_json
    result_node = result_json.get("result", {})
    contents = result_node.get("contents", [])
    for c in contents:
        if "markdown" in c:
            original = c["markdown"]
            decoded = _decode_unicode_escape_if_needed(original)
            c["markdown_decoded"] = decoded  # 新しいキーに保存 (元を上書きしない)
    return result_json

# 音声結果があればデコードして一部表示
if audio_result:
    audio_result = decode_markdown_in_result(audio_result)
    # 先頭の markdown_decoded を表示
    first = audio_result.get("result", {}).get("contents", [{}])[0].get("markdown_decoded", "(なし)")
    print("--- デコード済み Markdown (先頭) ---\n")
    print(first[:2000])

# 動画結果があれば同様
if 'video_result' in globals() and video_result:
    video_result = decode_markdown_in_result(video_result)
    first_v = video_result.get("result", {}).get("contents", [{}])[0].get("markdown_decoded", "(なし)")
    print("\n--- デコード済み 動画 Markdown (先頭) ---\n")
    print(first_v[:2000])

# %% [markdown]
# ## 動画コンテンツ解析
# ショット / キーフレーム / トランスクリプトなどを取得します。

# %%
# 非同期で動画を解析する例 (再試行付き)
import asyncio, json
from pathlib import Path

VIDEO_FILE = '../data/Dev Box Accessibility Up Close Demo.mp4'
VIDEO_ANALYZER_ID = 'prebuilt-videoAnalyzer'

async def run_video_async(max_retries: int = 3):
    if not Path(VIDEO_FILE).is_file():
        print(f'サンプル動画が見つかりません: {VIDEO_FILE}')
        return None
    attempt = 0
    last_err = None
    while attempt < max_retries:
        attempt += 1
        try:
            print(f'Video analyze attempt {attempt}/{max_retries} ...')
            result = await client.analyze_and_get_result_async(VIDEO_ANALYZER_ID, VIDEO_FILE)
            print(json.dumps(result, indent=2)[:3000] + '\n... 省略 ...')
            return result
        except Exception as e:
            last_err = e
            print(f'Attempt {attempt} failed: {e}')
            await asyncio.sleep(2 * attempt)  # バックオフ
    print('解析失敗: 最大リトライ回数に到達しました')
    if last_err:
        print('最後のエラー:', last_err)
    return None

video_result = await run_video_async()
# Out:
# Video analyze attempt 1/3 ...
# Attempt 1 failed: name 'client' is not defined
# Video analyze attempt 2/3 ...
# Attempt 2 failed: name 'client' is not defined
# Video analyze attempt 3/3 ...
# Attempt 3 failed: name 'client' is not defined
# 解析失敗: 最大リトライ回数に到達しました
# 最後のエラー: name 'client' is not defined

# %% [markdown]
# ### キーフレーム画像保存 (オプション)

# %%
if video_result:

# %% [markdown]
# ## まとめ
# このノートブックでは API キー方式で Content Understanding の基本的な解析 (ドキュメント / 音声 / 動画) を行う最小例を示しました。より高度なトレーニング / 参照ドキュメント生成 / 分類器機能が必要な場合は完全版クライアントを取得してください。
